# %% [markdown]
# # BIG MART SALES PREDICTION
# https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/

# %% [markdown]
# #Sales Prediction for Big Mart Outlets
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and predict the sales of each product at a particular outlet.
#
# Using this model, BigMart will try to understand the properties of products and outlets which play a key role in increasing sales.
#
# Please note that the data may have missing values as some stores might not report all the data due to technical glitches. Hence, it will be required to treat them accordingly.

# %% [markdown]
# ![bigmart_train_data.PNG](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/big_mart_train.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...  Supermarket Type1          3735.1380
# 1           DRC01         5.92  ...  Supermarket Type2           443.4228
# 2           FDN15        17.50  ...  Supermarket Type1          2097.2700
# 3           FDX07        19.20  ...      Grocery Store           732.3800
# 4           NCD19         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 8518           FDF22        6.865  ...  Supermarket Type1          2778.3834
# 8519           FDS36        8.380  ...  Supermarket Type1           549.2850
# 8520           NCJ29       10.600  ...  Supermarket Type1          1193.1136
# 8521           FDN46        7.210  ...  Supermarket Type2          1845.5976
# 8522           DRG01       14.800  ...  Supermarket Type1           765.6700
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.describe()
# Out:
#        Item_Weight  ...  Item_Outlet_Sales
# count  7060.000000  ...        8523.000000
# mean     12.857645  ...        2181.288914
# std       4.643456  ...        1706.499616
# min       4.555000  ...          33.290000
# 25%       8.773750  ...         834.247400
# 50%      12.600000  ...        1794.331000
# 75%      16.850000  ...        3101.296400
# max      21.350000  ...       13086.964800
#
# [8 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df[df['Item_Identifier']=='FDA15']
# Out:
#      Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0              FDA15          9.3  ...  Supermarket Type1          3735.1380
# 831            FDA15          9.3  ...  Supermarket Type1          5976.2208
# 2599           FDA15          9.3  ...  Supermarket Type1          6474.2392
# 2643           FDA15          9.3  ...  Supermarket Type2          5976.2208
# 4874           FDA15          9.3  ...      Grocery Store           498.0184
# 5413           FDA15          9.3  ...  Supermarket Type1          6474.2392
# 6696           FDA15          NaN  ...  Supermarket Type3          6474.2392
# 7543           FDA15          9.3  ...  Supermarket Type1          5976.2208
#
# [8 rows x 12 columns]

# %%
df[df['Item_Identifier']=='NCD19']
# Out:
#      Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 4              NCD19         8.93  ...  Supermarket Type1           994.7052
# 522            NCD19         8.93  ...      Grocery Store           276.3070
# 802            NCD19         8.93  ...  Supermarket Type1           331.5684
# 2129           NCD19         8.93  ...  Supermarket Type1           939.4438
# 2907           NCD19         8.93  ...  Supermarket Type1           828.9210
# 3428           NCD19         8.93  ...  Supermarket Type1           552.6140
#
# [6 rows x 12 columns]

# %% [markdown]
# # Preprocessing

# %%
item_weight_mean=df.pivot_table(values="Item_Weight",index='Item_Identifier')

# %%
item_weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
miss_bool=df['Item_Weight'].isnull()

# %%
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
for i,item in enumerate(df['Item_Identifier']):
  if miss_bool[i]:
    if item in item_weight_mean:
      df['Item_Weight'][i]=item_weight_mean.loc[item]['Item_Weight']
    else:
      df['Item_Weight'][i]=np.mean(df['Item_Weight'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df[df['Item_Identifier']=='FDN52']
# Out:
#     Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 927           FDN52    12.857645  ...  Supermarket Type3          1569.9564
#
# [1 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
outlet_size_mode=df.pivot_table(values='Outlet_Size',columns='Outlet_Type',aggfunc=(lambda x: x.mode()[0]))

# %%
outlet_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2 Supermarket Type3
# Outlet_Size         Small             Small            Medium            Medium

# %%
miss_bool=df['Outlet_Size'].isnull()

# %%
df.loc[miss_bool,'Outlet_Size']=df.loc[miss_bool,'Outlet_Type'].apply(lambda x: outlet_size_mode[x])

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df[df['Item_Visibility']==0]
# Out:
#      Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 3              FDX07    19.200000  ...      Grocery Store           732.3800
# 4              NCD19     8.930000  ...  Supermarket Type1           994.7052
# 5              FDP36    10.395000  ...  Supermarket Type2           556.6088
# 10             FDY07    11.800000  ...  Supermarket Type1          1516.0266
# 32             FDP33    18.700000  ...  Supermarket Type2          3068.0064
# ...              ...          ...  ...                ...                ...
# 8480           FDQ58    12.857645  ...      Grocery Store           459.4020
# 8484           DRJ49     6.865000  ...  Supermarket Type1          2324.9736
# 8486           FDR20    20.000000  ...      Grocery Store            45.2744
# 8494           NCI54    15.200000  ...  Supermarket Type1          1637.8680
# 8500           NCQ42    20.350000  ...  Supermarket Type1          1907.5170
#
# [526 rows x 12 columns]

# %%
df.loc[:,'Item_Visibility'].replace([0],[df['Item_Visibility'].mean()],inplace=True)

# %%
df[df['Item_Visibility']==0]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'})

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df['Outlet_Years']=2013-df['Outlet_Establishment_Year']

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  ... Item_Outlet_Sales  Outlet_Years
# 0           FDA15         9.30  ...         3735.1380            14
# 1           DRC01         5.92  ...          443.4228             4
# 2           FDN15        17.50  ...         2097.2700            14
# 3           FDX07        19.20  ...          732.3800            15
# 4           NCD19         8.93  ...          994.7052            26
#
# [5 rows x 13 columns]

# %%
df['New_Item_Type']=df['Item_Identifier'].apply(lambda x: x[:2])

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  ... Outlet_Years  New_Item_Type
# 0           FDA15         9.30  ...           14             FD
# 1           DRC01         5.92  ...            4             DR
# 2           FDN15        17.50  ...           14             FD
# 3           FDX07        19.20  ...           15             FD
# 4           NCD19         8.93  ...           26             NC
#
# [5 rows x 14 columns]

# %%
df['New_Item_Type']=df['New_Item_Type'].map({'FD':'Food','NC':'Non Consumable','DR':'Drinks'})

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  ... Outlet_Years   New_Item_Type
# 0           FDA15         9.30  ...           14            Food
# 1           DRC01         5.92  ...            4          Drinks
# 2           FDN15        17.50  ...           14            Food
# 3           FDX07        19.20  ...           15            Food
# 4           NCD19         8.93  ...           26  Non Consumable
#
# [5 rows x 14 columns]

# %%
df.loc[df['New_Item_Type']=='Non Consumable','Item_Fat_Content']='Non Edible'

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
sns.distplot(df['Item_Visibility'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(df["Item_Fat_Content"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df[df["Item_Fat_Content"]=='Non Edible']
# Out:
#      Item_Identifier  Item_Weight  ... Outlet_Years   New_Item_Type
# 4              NCD19     8.930000  ...           26  Non Consumable
# 16             NCB42    11.800000  ...            4  Non Consumable
# 22             NCB30    14.600000  ...            9  Non Consumable
# 25             NCD06    13.000000  ...            6  Non Consumable
# 31             NCS17    18.600000  ...            4  Non Consumable
# ...              ...          ...  ...          ...             ...
# 8500           NCQ42    20.350000  ...            6  Non Consumable
# 8502           NCH43     8.420000  ...           11  Non Consumable
# 8504           NCN18    12.857645  ...           28  Non Consumable
# 8516           NCJ19    18.600000  ...            4  Non Consumable
# 8520           NCJ29    10.600000  ...            9  Non Consumable
#
# [1599 rows x 14 columns]

# %%
l = list(df['Item_Type'].unique())
chart = sns.countplot(df["Item_Type"])
chart.set_xticklabels(labels=l, rotation=90)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0, 0, 'Dairy'),
#  Text(0, 0, 'Soft Drinks'),
#  Text(0, 0, 'Meat'),
#  Text(0, 0, 'Fruits and Vegetables'),
#  Text(0, 0, 'Household'),
#  Text(0, 0, 'Baking Goods'),
#  Text(0, 0, 'Snack Foods'),
#  Text(0, 0, 'Frozen Foods'),
#  Text(0, 0, 'Breakfast'),
#  Text(0, 0, 'Health and Hygiene'),
#  Text(0, 0, 'Hard Drinks'),
#  Text(0, 0, 'Canned'),
#  Text(0, 0, 'Breads'),
#  Text(0, 0, 'Starchy Foods'),
#  Text(0, 0, 'Others'),
#  Text(0, 0, 'Seafood')]

# %%
df = pd.get_dummies(df, columns=['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type'])
df.head()
# Out:
#   Item_Identifier  ...  New_Item_Type_Non Consumable
# 0           FDA15  ...                             0
# 1           DRC01  ...                             0
# 2           FDN15  ...                             0
# 3           FDX07  ...                             0
# 4           NCD19  ...                             1
#
# [5 rows x 25 columns]

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT035    930
# OUT046    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Item_Type']=le.fit_transform(df['Item_Type'])

# %%
df['Outlet_Identifier']=le.fit_transform(df['Outlet_Identifier'])

# %%
df.head()
# Out:
#   Item_Identifier  ...  New_Item_Type_Non Consumable
# 0           FDA15  ...                             0
# 1           DRC01  ...                             0
# 2           FDN15  ...                             0
# 3           FDX07  ...                             0
# 4           NCD19  ...                             1
#
# [5 rows x 25 columns]

# %% [markdown]
# # Hypotheses

# %% [markdown]
# Hypotheses [examples](https://www.kaggle.com/brajkishore8963/eda-and-hypothesis-testing-on-bigmart-sales-data).
#
# *   Item weight might effect a sales of the product.
# *   Sales of the product may be depends on the items fat content.
# *   More Item_Visibility of a particular product may be costlier than other products.
# *   Item type could have an effect on the sales.
# *    Are the items with more MRP have more item outlet sales.
# *    Are the stores which have established earlier have more sales.
# *    Size of the stores could have an effect on the item sales at a particular store.
# *    Location of the stores might depends on the Item outlet sales.
# *    Are the supermarkets have more sales than others.

# %% [markdown]
# # Prediction

# %%
X=df.drop(columns=['Item_Identifier','Outlet_Establishment_Year','Item_Outlet_Sales'])
y=df['Item_Outlet_Sales']

# %%
X.head()
# Out:
#    Item_Weight  ...  New_Item_Type_Non Consumable
# 0         9.30  ...                             0
# 1         5.92  ...                             0
# 2        17.50  ...                             0
# 3        19.20  ...                             0
# 4         8.93  ...                             1
#
# [5 rows x 22 columns]

# %%
X.shape
# Out:
# (8523, 22)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model = model.fit(X_train,y_train)
predict = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,predict))
# Out:
# 0.5642111586798384

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, predict)
# Out:
# 1275492.6896617946
